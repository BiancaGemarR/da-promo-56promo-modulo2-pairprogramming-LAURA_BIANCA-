# %%
for anio in range(2011,2022):

# %%
import requests
import pandas as pd

# %%
url = "https://apidatos.ree.es//es/datos/generacion/estructura-generacion?start_date=2022-01-01T00:00&end_date=2022-12-31T23:59&time_trunc=month"

# %%
"url = https://apidatos.ree.es/es/datos/generacion/evolucion-renovable-no-renovable?start_date=2011-01-01T00:00&end_date=2022-12-31T23:59&time_trunc=month"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.reason
# Out:
# 'OK'

# %%
response.json()
# Out:
# {'data': {'type': 'Generación por tecnología',
#   'id': 'gen1',
#   'attributes': {'title': 'Generación por tecnología',
#    'last-update': '2022-12-12T12:48:47.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'Hidráulica',
#    'id': '10288',
#    'groupId': '1',
#    'attributes': {'title': 'Hidráulica',
#     'description': None,
#     'color': '#0090d1',
#     'icon': None,
#     'type': 'Renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2022-12-12T12:48:38.000+01:00',
#     'values': [{'value': 2085857.451,
#       'percentage': 0.0865979014431461,
#       'datetime': '2022-01-01T00:00:00.000+01:00'},
#      {'value': 1174970.17,
#       'percentage': 0.05639231065537004,
#       'datetime': '2022-02-01T00:00:00.000+01:00'},
#      {'value': 1775478.144,
#       'percentage': 0.07892461852124848,
#       'datetime': '2022-03-01T00:00:00.000+01:00'},
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['data', 'included'])

# %%
response.json()['data']
# Out:
# {'type': 'Generación por tecnología',
#  'id': 'gen1',
#  'attributes': {'title': 'Generación por tecnología',
#   'last-update': '2022-12-12T12:48:47.000+01:00',
#   'description': None},
#  'meta': {'cache-control': {'cache': 'MISS'}}}

# %%
response.json()['included']
# Out:
# [{'type': 'Hidráulica',
#   'id': '10288',
#   'groupId': '1',
#   'attributes': {'title': 'Hidráulica',
#    'description': None,
#    'color': '#0090d1',
#    'icon': None,
#    'type': 'Renovable',
#    'magnitude': None,
#    'composite': False,
#    'last-update': '2022-12-12T12:48:38.000+01:00',
#    'values': [{'value': 2085857.451,
#      'percentage': 0.0865979014431461,
#      'datetime': '2022-01-01T00:00:00.000+01:00'},
#     {'value': 1174970.17,
#      'percentage': 0.05639231065537004,
#      'datetime': '2022-02-01T00:00:00.000+01:00'},
#     {'value': 1775478.144,
#      'percentage': 0.07892461852124848,
#      'datetime': '2022-03-01T00:00:00.000+01:00'},
#     {'value': 1802751.588,
#      'percentage': 0.08409999181045708,
#      'datetime': '2022-04-01T00:00:00.000+02:00'},
#     {'value': 1923714.557,
#      'percentage': 0.08841221262000502,
#      'datetime': '2022-05-01T00:00:00.000+02:00'},
#     {'value': 1192915.008,
# ...

# %%
response.json()['included'][0]
# Out:
# {'type': 'Hidráulica',
#  'id': '10288',
#  'groupId': '1',
#  'attributes': {'title': 'Hidráulica',
#   'description': None,
#   'color': '#0090d1',
#   'icon': None,
#   'type': 'Renovable',
#   'magnitude': None,
#   'composite': False,
#   'last-update': '2022-12-12T12:48:38.000+01:00',
#   'values': [{'value': 2085857.451,
#     'percentage': 0.0865979014431461,
#     'datetime': '2022-01-01T00:00:00.000+01:00'},
#    {'value': 1174970.17,
#     'percentage': 0.05639231065537004,
#     'datetime': '2022-02-01T00:00:00.000+01:00'},
#    {'value': 1775478.144,
#     'percentage': 0.07892461852124848,
#     'datetime': '2022-03-01T00:00:00.000+01:00'},
#    {'value': 1802751.588,
#     'percentage': 0.08409999181045708,
#     'datetime': '2022-04-01T00:00:00.000+02:00'},
#    {'value': 1923714.557,
#     'percentage': 0.08841221262000502,
#     'datetime': '2022-05-01T00:00:00.000+02:00'},
#    {'value': 1192915.008,
#     'percentage': 0.051898346939567054,
# ...

# %%
response.json()['included'][0]['type']
# Out:
# 'Hidráulica'

# %%
response.json()['included'][0].keys()
# Out:
# dict_keys(['type', 'id', 'groupId', 'attributes'])

# %%
response.json()['included'][0]['attributes']
# Out:
# {'title': 'Hidráulica',
#  'description': None,
#  'color': '#0090d1',
#  'icon': None,
#  'type': 'Renovable',
#  'magnitude': None,
#  'composite': False,
#  'last-update': '2022-12-12T12:48:38.000+01:00',
#  'values': [{'value': 2085857.451,
#    'percentage': 0.0865979014431461,
#    'datetime': '2022-01-01T00:00:00.000+01:00'},
#   {'value': 1174970.17,
#    'percentage': 0.05639231065537004,
#    'datetime': '2022-02-01T00:00:00.000+01:00'},
#   {'value': 1775478.144,
#    'percentage': 0.07892461852124848,
#    'datetime': '2022-03-01T00:00:00.000+01:00'},
#   {'value': 1802751.588,
#    'percentage': 0.08409999181045708,
#    'datetime': '2022-04-01T00:00:00.000+02:00'},
#   {'value': 1923714.557,
#    'percentage': 0.08841221262000502,
#    'datetime': '2022-05-01T00:00:00.000+02:00'},
#   {'value': 1192915.008,
#    'percentage': 0.051898346939567054,
#    'datetime': '2022-06-01T00:00:00.000+02:00'},
#   {'value': 1045015.928,
#    'percentage': 0.03987332754831628,
# ...

# %%
response.json()['included'][0]['attributes'].keys()
# Out:
# dict_keys(['title', 'description', 'color', 'icon', 'type', 'magnitude', 'composite', 'last-update', 'values'])

# %%
response.json()['included'][0]['attributes']['type']
# Out:
# 'Renovable'

# %%
response.json()['included'][0]['attributes']['values']
# Out:
# [{'value': 2085857.451,
#   'percentage': 0.0865979014431461,
#   'datetime': '2022-01-01T00:00:00.000+01:00'},
#  {'value': 1174970.17,
#   'percentage': 0.05639231065537004,
#   'datetime': '2022-02-01T00:00:00.000+01:00'},
#  {'value': 1775478.144,
#   'percentage': 0.07892461852124848,
#   'datetime': '2022-03-01T00:00:00.000+01:00'},
#  {'value': 1802751.588,
#   'percentage': 0.08409999181045708,
#   'datetime': '2022-04-01T00:00:00.000+02:00'},
#  {'value': 1923714.557,
#   'percentage': 0.08841221262000502,
#   'datetime': '2022-05-01T00:00:00.000+02:00'},
#  {'value': 1192915.008,
#   'percentage': 0.051898346939567054,
#   'datetime': '2022-06-01T00:00:00.000+02:00'},
#  {'value': 1045015.928,
#   'percentage': 0.03987332754831628,
#   'datetime': '2022-07-01T00:00:00.000+02:00'},
#  {'value': 973565.249,
#   'percentage': 0.0390261951767793,
#   'datetime': '2022-08-01T00:00:00.000+02:00'},
#  {'value': 1154833.141,
#   'percentage': 0.04943333542177474,
# ...

# %%
response.json()['included'][0]['attributes']['values'][0]
# Out:
# {'value': 1174970.17,
#  'percentage': 0.05639231065537004,
#  'datetime': '2022-02-01T00:00:00.000+01:00'}

# %%
response.json()['included'][0]['attributes']['values'][0]['value']
# Out:
# 2085857.451

# %%
response.json()['included'][0]['attributes']['values'][0]['datetime']
# Out:
# '2022-01-01T00:00:00.000+01:00'

# %%
fecha_2022 = lista_2022["fecha"].append(response.json()['included'][0]['attributes']['values'][0]['datetime'])
for month in response.json():
    lista_2022 = {"tipo_energia": [], "tipo_generacion": [], "fecha": [], "valor":[]}
    lista_2022["tipo_energia"].append(response.json()['included'][0]['type'])
    lista_2022["tipo_generacion"].append(response.json()['included'][0]['attributes']['type'])
    lista_2022["fecha"].append(response.json()['included'][0]['attributes']['values'][0]['datetime'])
    lista_2022["valor"].append(response.json()['included'][0]['attributes']['values'][0]['value'])

# %%
lista_2022
# Out:
# {'tipo_energia': ['Hidráulica'],
#  'tipo_generacion': ['Renovable'],
#  'fecha': ['2022-01-01T00:00:00.000+01:00'],
#  'valor': [2085857.451]}

# %%
#falta definir datos, respuesta clase
for e in datos['included']:

    print(e['title'])
    for dato in e['attributes']['values']:
        print(e(["attributes"]['values']))
        print(e(["type"]))
        print(dato['value'])
        print(dato['datetime'])
# Out:
# <>:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\grbia\AppData\Local\Temp\ipykernel_11156\1952808903.py:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   print(e(["attributes"]['values']))
# C:\Users\grbia\AppData\Local\Temp\ipykernel_11156\1952808903.py:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   print(e(["attributes"]['values']))
# C:\Users\grbia\AppData\Local\Temp\ipykernel_11156\1952808903.py:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   print(e(["attributes"]['values']))
# C:\Users\grbia\AppData\Local\Temp\ipykernel_11156\1952808903.py:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ...

# %% [markdown]
# Cómo seguir con el ejercicio: resuelto por César en clase

# %%
datos["included"][0]["attributes"]["values"][1]["datetime"]

# cada [0] o [1] será una iteración dentro de la lista, por eso:

for e in datos["included"]: # priemra iteración dentro de "included"

    for dato in e["attributes"]["values"]: # segunda iteración dentro de attributes y values
        print(e["attributes"]["title"])  # queremos el dato del title que salen en attributes
        print(e["attributes"]["type"])  # queremos el dato del type que salen en attributes
        print(dato["value"])           # queremos el dato del value que salen dentro de datos["included"][0]["attributes"]["values"][1]
        print(dato["datetime"])        # queremos el dato del datetime que salen dentro de datos["included"][0]["attributes"]["values"][1]
        print("--------------------")
        break


# queremos un diccionari para cada año
diccionario_año = {"tipo": [], "título": [], "fecha": [], "valor":[]}

for e in datos["included"]: 

    for dato in e["attributes"]["values"]: 

        diccionario_año["tipo"].append(e["attributes"]["title"])  # queremos añadir el dato del title que salen en attributes
        diccionario_año["título"].append(e["attributes"]["type"])  # queremos añadir el dato del type que salen en attributes
        diccionario_año["fecha"].append(dato["value"])           # queremos añadir el dato del value que salen dentro de datos["included"][0]["attributes"]["values"][1]
        diccionario_año["valor"].append(dato["datetime"])        # queremos añadir el dato del datetime que salen dentro de datos["included"][0]["attributes"]["values"][1]
        print("--------------------")
        break

# para crear la tabla:
pd.DataFrame(diccionario_año).head(20)

## pero nos piden para varios años:

for a in range(2011, 2021): # le decimos que "a" vaya teniendo valores dentro del rago de años 2011-2020
    url = f"https://apidatos.ree......?start_date={a}-01-01T00:00&end_date={a}-12-31T23:59&time_trunc=month"
    response = requests.get(url)
    datos = response.json()

# y tenemos que incluir lo anterior dentro:

diccionario_año = {"tipo": [], "título": [], "fecha": [], "valor":[]}

for a in range(2011, 2020): # primera iteración dentro del primer año
    url = f"https://apidatos.ree......?start_date={a}-01-01T00:00&end_date={a}-12-31T23:59&time_trunc=month"
    response = requests.get(url)
    print(url)
    datos = response.json()

    for e in datos["included"]: # segunda iteración dentro de "included"

        for dato in e["attributes"]["values"]: # tercera iteración dentro de attributes y values

        diccionario_año["tipo"].append(e["attributes"]["title"])  # queremos añadir el dato del title que salen en attributes
        diccionario_año["título"].append(e["attributes"]["type"])  # queremos añadir el dato del type que salen en attributes
        diccionario_año["fecha"].append(dato["value"])           # queremos añadir el dato del value que salen dentro de datos["included"][0]["attributes"]["values"][1]
        diccionario_año["valor"].append(dato["datetime"])        # queremos añadir el dato del datetime que salen dentro de datos["included"][0]["attributes"]["values"][1]
        print("--------------------")
        break

# y finalmente crear la tabla total:
pd.DataFrame(diccionario_año).head(20) ## el .head() nos muestra una idea de la tabla o .head(20) los primeros 20 datos
